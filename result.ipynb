# %%
import cv2
from time import time
import numpy as np
from ultralytics.solutions.solutions import BaseSolution
from ultralytics.utils.plotting import Annotator, colors
from datetime import datetime
from paddleocr import PaddleOCR
import pandas as pd
from ultralytics import YOLO

# %%
model = YOLO(r"D:\Prabha\Cubeai_intern\Construction\Source_codes\Number Plate Recognition (NPR)\runs\detect\train\weights\best.pt")

# %%
video = r"D:\Prabha\Cubeai_intern\Construction\Licence Plate Camera Illustration Video(1080P_HD).mp4"

# %%
class SpeedEstimator(BaseSolution):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.initialize_region()
        self.spd = {}
        self.trkd_ids = []
        self.trk_pt = {}
        self.trk_pp = {}
        self.logged_ids = set()
        self.ocr = PaddleOCR(use_angle_cls=True, lang='en')
        self.excel_file = "speed_estimation.xlsx"
        self.init_excel()

    def init_excel(self):
        columns = ["Date", "Time", "Track ID", "Class Name", "Speed", "Number Plate"]
        try:
            pd.read_excel(self.excel_file)
        except FileNotFoundError:
            pd.DataFrame(columns=columns).to_excel(self.excel_file, index=False)

    def perform_ocr(self, image_array):
        if image_array is None:
            raise ValueError("Image is None")
        if isinstance(image_array, np.ndarray):
            results = self.ocr.ocr(image_array, rec=True)
        else:
            raise TypeError("Input image is not a valid numpy array")
        return ' '.join([result[1][0] for result in results[0]] if results[0] else "")

    def save_to_excel(self, date, time, track_id, class_name, speed, numberplate):
        data = pd.DataFrame([[date, time, track_id, class_name, speed, numberplate]],
                            columns=["Date", "Time", "Track ID", "Class Name", "Speed", "Number Plate"])
        existing_data = pd.read_excel(self.excel_file)
        updated_data = pd.concat([existing_data, data], ignore_index=True)
        updated_data.to_excel(self.excel_file, index=False)

    def estimate_speed(self, im0):
        self.annotator = Annotator(im0, line_width=self.line_width)
        self.extract_tracks(im0)
        current_time = datetime.now()

        for box, track_id, cls in zip(self.boxes, self.track_ids, self.clss):
            self.store_tracking_history(track_id, box)

            if track_id not in self.trk_pt:
                self.trk_pt[track_id] = 0
            if track_id not in self.trk_pp:
                self.trk_pp[track_id] = self.track_line[-1]

            speed_label = f"{int(self.spd[track_id])} km/h" if track_id in self.spd else self.names[int(cls)]
            label = f"ID: {track_id} {speed_label}"
            self.annotator.box_label(box, label=label, color=colors(track_id, True))

            if self.LineString([self.trk_pp[track_id], self.track_line[-1]]).intersects(self.r_s):
                direction = "known"
            else:
                direction = "unknown"

            if direction == "known" and track_id not in self.trkd_ids:
                self.trkd_ids.append(track_id)
                time_difference = time() - self.trk_pt[track_id]
                if time_difference > 0:
                    speed = np.abs(self.track_line[-1][1].item() - self.trk_pp[track_id][1].item()) / time_difference
                    self.spd[track_id] = round(speed)

            self.trk_pt[track_id] = time()
            self.trk_pp[track_id] = self.track_line[-1]
            x1, y1, x2, y2 = map(int, box)
            cropped_image = np.array(im0)[y1:y2, x1:x2]
            ocr_text = self.perform_ocr(cropped_image)
            class_name = self.names[int(cls)]
            speed = self.spd.get(track_id)

            if track_id not in self.logged_ids and ocr_text.strip() and speed is not None:
                self.save_to_excel(
                    current_time.strftime("%Y-%m-%d"),
                    current_time.strftime("%H:%M:%S"),
                    track_id,
                    class_name,
                    speed if speed is not None else 0.0,
                    ocr_text
                )
                self.logged_ids.add(track_id)

        self.display_output(im0)
        return im0
    
    def RGB(self, event, x, y, flags, param):
        if event == cv2.EVENT_MOUSEMOVE:
            point = [x, y]

cap = cv2.VideoCapture(video)
region_points = [(0, 315), (1018, 315)]
speed_obj = SpeedEstimator(
    region=region_points,
    model=r"D:\Prabha\Cubeai_intern\Construction\Source_codes\Number Plate Recognition (NPR)\runs\detect\train\weights\best.pt",
    line_width=2
)

count = 0
cv2.namedWindow("RGB")
cv2.setMouseCallback("RGB", speed_obj.RGB)
while True:
    ret, frame = cap.read()
    if not ret:
        break

    count += 1
    if count % 3 != 0:
        continue

    frame = cv2.resize(frame, (1020, 500))
    result = speed_obj.estimate_speed(frame)
    cv2.imshow("RGB", result)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Ultralytics Solutions:  {'region': [(0, 315), (1018, 315)], 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'model': 'D:\\Prabha\\Cubeai_intern\\Construction\\Source_codes\\Number Plate Recognition (NPR)\\runs\\detect\\train\\weights\\best.pt', 'line_width': 2}
# [2025/03/24 15:33:33] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Jarvis/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Jarvis/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\Jarvis\\anaconda3\\envs\\without\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\Jarvis/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
#
# 0: 320x640 (no detections), 68.8ms
# Speed: 2.2ms preprocess, 68.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 139.1ms
# Speed: 1.0ms preprocess, 139.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 38.4ms
# Speed: 1.1ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections),
ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 34.9ms
# Speed: 1.1ms preprocess, 34.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 3 License_Plates, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 34.0ms
# Speed: 1.2ms preprocess, 34.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 33.6ms
# Speed: 1.1ms preprocess, 33.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 34.6ms
# Speed: 1.2ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 32.8ms
# Speed: 1.0ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 32.2ms
# Speed: 1.0ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 33.1ms
# Speed: 1.2ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:40] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0768587589263916
# [2025/03/24 15:33:40] ppocr DEBUG: cls num  : 1, elapsed : 0.02491307258605957
# [2025/03/24 15:33:40] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10775971412658691
#
# 0: 320x640 1 License_Plate, 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:40] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0
# [2025/03/24 15:33:40] ppocr DEBUG: cls num  : 1, elapsed : 0.012537240982055664
# [2025/03/24 15:33:40] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0507354736328125
#
# 0: 320x640 1 License_Plate, 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:40] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0006806850433349609
# [2025/03/24 15:33:40] ppocr DEBUG: cls num  : 1, elapsed : 0.005986452102661133
# [2025/03/24 15:33:40] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04860830307006836
#
# 0: 320x640 1 License_Plate, 46.4ms
# Speed: 1.5ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:40] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010124921798706055
# [2025/03/24 15:33:40] ppocr DEBUG: cls num  : 1, elapsed : 0.0021114349365234375
# [2025/03/24 15:33:40] ppocr DEBUG: rec_res num  : 1, elapsed : 0.043457984924316406
#
# 0: 320x640 1 License_Plate, 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:41] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.04039478302001953
# [2025/03/24 15:33:41] ppocr DEBUG: cls num  : 1, elapsed : 0.0029828548431396484
# [2025/03/24 15:33:41] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05018949508666992
#
# 0: 320x640 1 License_Plate, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:41] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.007917165756225586
# [2025/03/24 15:33:41] ppocr DEBUG: cls num  : 1, elapsed : 0.0003161430358886719
# [2025/03/24 15:33:41] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05293917655944824
#
# 0: 320x640 1 License_Plate, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:41] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0
# [2025/03/24 15:33:41] ppocr DEBUG: cls num  : 1, elapsed : 0.0069773197174072266
# [2025/03/24 15:33:41] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0508265495300293
#
# 0: 320x640 1 License_Plate, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:41] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.005012035369873047
# [2025/03/24 15:33:41] ppocr DEBUG: cls num  : 1, elapsed : 0.0035469532012939453
# [2025/03/24 15:33:41] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04617452621459961
#
# 0: 320x640 1 License_Plate, 46.1ms
# Speed: 1.2ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:41] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.003987789154052734
# [2025/03/24 15:33:41] ppocr DEBUG: cls num  : 1, elapsed : 0.003223419189453125
# [2025/03/24 15:33:41] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05079007148742676
#
# 0: 320x640 1 License_Plate, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:41] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.006893634796142578
# [2025/03/24 15:33:41] ppocr DEBUG: cls num  : 1, elapsed : 0.0
# [2025/03/24 15:33:41] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05061483383178711
#
# 0: 320x640 1 License_Plate, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:41] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.007121562957763672
# [2025/03/24 15:33:41] ppocr DEBUG: cls num  : 1, elapsed : 0.0020024776458740234
# [2025/03/24 15:33:41] ppocr DEBUG: rec_res num  : 1, elapsed : 0.052405357360839844
#
# 0: 320x640 1 License_Plate, 47.7ms
# Speed: 1.2ms preprocess, 47.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:42] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.007095813751220703
# [2025/03/24 15:33:42] ppocr DEBUG: cls num  : 1, elapsed : 0.0
# [2025/03/24 15:33:42] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05566811561584473
#
# 0: 320x640 1 License_Plate, 45.7ms
# Speed: 1.2ms preprocess, 45.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:42] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0033740997314453125
# [2025/03/24 15:33:42] ppocr DEBUG: cls num  : 1, elapsed : 0.0034160614013671875
# [2025/03/24 15:33:42] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04392647743225098
#
# 0: 320x640 1 License_Plate, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:42] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.0
# [2025/03/24 15:33:42] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/03/24 15:33:42] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
#
# 0: 320x640 (no detections), 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.5ms
# Speed: 1.2ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 48.7ms
# Speed: 1.2ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.0ms
# Speed: 2.2ms preprocess, 46.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 62.6ms
# Speed: 1.6ms preprocess, 62.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 47.6ms
# Speed: 1.1ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 48.0ms
# Speed: 1.2ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.6ms
# Speed: 1.4ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 47.1ms
# Speed: 1.1ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 47.3ms
# Speed: 1.1ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.0ms
# Speed: 1.4ms preprocess, 46.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.1ms
# Speed: 1.1ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.0ms
# Speed: 1.2ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.1ms
# Speed: 1.1ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.5ms
# Speed: 1.3ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.3ms
# Speed: 1.2ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.7ms
# Speed: 1.2ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.1ms
# Speed: 1.1ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.8ms
# Speed: 1.3ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.2ms
# Speed: 1.2ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.8ms
# Speed: 1.2ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.5ms
# Speed: 1.1ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:47] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.004359245300292969
# [2025/03/24 15:33:47] ppocr DEBUG: cls num  : 1, elapsed : 0.0030825138092041016
# [2025/03/24 15:33:47] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04876399040222168
#
# 0: 320x640 1 License_Plate, 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:47] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.004700899124145508
# [2025/03/24 15:33:47] ppocr DEBUG: cls num  : 1, elapsed : 0.0031561851501464844
# [2025/03/24 15:33:47] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05089068412780762
#
# 0: 320x640 1 License_Plate, 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:47] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0
# [2025/03/24 15:33:47] ppocr DEBUG: cls num  : 1, elapsed : 0.010445117950439453
# [2025/03/24 15:33:47] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05068349838256836
#
# 0: 320x640 1 License_Plate, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:47] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0038061141967773438
# [2025/03/24 15:33:47] ppocr DEBUG: cls num  : 1, elapsed : 0.0020532608032226562
# [2025/03/24 15:33:47] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04475998878479004
#
# 0: 320x640 1 License_Plate, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:47] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010007143020629883
# [2025/03/24 15:33:47] ppocr DEBUG: cls num  : 1, elapsed : 0.002004384994506836
# [2025/03/24 15:33:47] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04235219955444336
#
# 0: 320x640 1 License_Plate, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 51.5ms
# Speed: 1.2ms preprocess, 51.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 58.6ms
# Speed: 1.9ms preprocess, 58.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 51.3ms
# Speed: 1.3ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 63.6ms
# Speed: 1.3ms preprocess, 63.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 49.1ms
# Speed: 1.7ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 71.3ms
# Speed: 2.6ms preprocess, 71.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 48.5ms
# Speed: 1.2ms preprocess, 48.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 2 License_Plates, 71.7ms
# Speed: 2.8ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 110.4ms
# Speed: 2.3ms preprocess, 110.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 101.5ms
# Speed: 1.3ms preprocess, 101.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 99.7ms
# Speed: 2.6ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 81.8ms
# Speed: 1.4ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 78.3ms
# Speed: 1.1ms preprocess, 78.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:49] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0
# [2025/03/24 15:33:49] ppocr DEBUG: cls num  : 1, elapsed : 0.0
# [2025/03/24 15:33:49] ppocr DEBUG: rec_res num  : 1, elapsed : 0.09223127365112305
#
# 0: 320x640 1 License_Plate, 89.9ms
# Speed: 1.2ms preprocess, 89.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:50] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01160287857055664
# [2025/03/24 15:33:50] ppocr DEBUG: cls num  : 1, elapsed : 0.004484653472900391
# [2025/03/24 15:33:50] ppocr DEBUG: rec_res num  : 1, elapsed : 0.06021690368652344
#
# 0: 320x640 1 License_Plate, 89.9ms
# Speed: 1.2ms preprocess, 89.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:50] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010768651962280273
# [2025/03/24 15:33:50] ppocr DEBUG: cls num  : 1, elapsed : 0.006566286087036133
# [2025/03/24 15:33:50] ppocr DEBUG: rec_res num  : 1, elapsed : 0.3963656425476074
#
# 0: 320x640 1 License_Plate, 66.9ms
# Speed: 1.1ms preprocess, 66.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:50] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.004886627197265625
# [2025/03/24 15:33:50] ppocr DEBUG: cls num  : 1, elapsed : 0.003060579299926758
# [2025/03/24 15:33:50] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051779985427856445
#
# 0: 320x640 1 License_Plate, 74.8ms
# Speed: 1.1ms preprocess, 74.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 1 License_Plate, 88.7ms
# Speed: 1.4ms preprocess, 88.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:51] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.004003047943115234
# [2025/03/24 15:33:51] ppocr DEBUG: cls num  : 1, elapsed : 0.0
# [2025/03/24 15:33:51] ppocr DEBUG: rec_res num  : 1, elapsed : 0.07416439056396484
#
# 0: 320x640 1 License_Plate, 75.2ms
# Speed: 1.1ms preprocess, 75.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:51] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.002521514892578125
# [2025/03/24 15:33:51] ppocr DEBUG: cls num  : 1, elapsed : 0.009950637817382812
# [2025/03/24 15:33:51] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13109517097473145
#
# 0: 320x640 1 License_Plate, 96.9ms
# Speed: 2.3ms preprocess, 96.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:51] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009433507919311523
# [2025/03/24 15:33:51] ppocr DEBUG: cls num  : 1, elapsed : 0.007827281951904297
# [2025/03/24 15:33:51] ppocr DEBUG: rec_res num  : 1, elapsed : 0.17670607566833496
#
# 0: 320x640 1 License_Plate, 87.7ms
# Speed: 2.8ms preprocess, 87.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:52] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009420156478881836
# [2025/03/24 15:33:52] ppocr DEBUG: cls num  : 1, elapsed : 0.008554458618164062
# [2025/03/24 15:33:52] ppocr DEBUG: rec_res num  : 1, elapsed : 0.2718315124511719
#
# 0: 320x640 1 License_Plate, 105.6ms
# Speed: 2.9ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:52] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.006437540054321289
# [2025/03/24 15:33:52] ppocr DEBUG: cls num  : 1, elapsed : 0.011659622192382812
# [2025/03/24 15:33:52] ppocr DEBUG: rec_res num  : 1, elapsed : 0.35974788665771484
#
# 0: 320x640 1 License_Plate, 95.9ms
# Speed: 2.3ms preprocess, 95.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:52] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010141372680664062
# [2025/03/24 15:33:52] ppocr DEBUG: cls num  : 1, elapsed : 0.007464885711669922
# [2025/03/24 15:33:53] ppocr DEBUG: rec_res num  : 1, elapsed : 0.33252501487731934
#
# 0: 320x640 1 License_Plate, 114.8ms
# Speed: 2.6ms preprocess, 114.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# [2025/03/24 15:33:53] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01277923583984375
# [2025/03/24 15:33:53] ppocr DEBUG: cls num  : 1, elapsed : 0.007978439331054688
# [2025/03/24 15:33:53] ppocr DEBUG: rec_res num  : 1, elapsed : 0.34606432914733887
#
# 0: 320x640 (no detections), 73.1ms
# Speed: 1.4ms preprocess, 73.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 80.4ms
# Speed: 1.2ms preprocess, 80.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 69.8ms
# Speed: 1.7ms preprocess, 69.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 86.5ms
# Speed: 1.1ms preprocess, 86.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 80.3ms
# Speed: 1.1ms preprocess, 80.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 79.9ms
# Speed: 1.1ms preprocess, 79.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 59.5ms
# Speed: 1.2ms preprocess, 59.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 69.6ms
# Speed: 1.4ms preprocess, 69.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 54.3ms
# Speed: 1.1ms preprocess, 54.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 71.1ms
# Speed: 1.3ms preprocess, 71.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 74.1ms
# Speed: 1.2ms preprocess, 74.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 93.5ms
# Speed: 1.3ms preprocess, 93.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 113.0ms
# Speed: 2.7ms preprocess, 113.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 48.3ms
# Speed: 1.1ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.8ms
# Speed: 2.1ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.0ms
# Speed: 1.2ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 46.6ms
# Speed: 1.3ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.5ms
# Speed: 1.2ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 92.2ms
# Speed: 1.8ms preprocess, 92.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 81.8ms
# Speed: 1.3ms preprocess, 81.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 77.2ms
# Speed: 1.2ms preprocess, 77.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 72.6ms
# Speed: 1.1ms preprocess, 72.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 86.8ms
# Speed: 1.2ms preprocess, 86.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 90.9ms
# Speed: 3.0ms preprocess, 90.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections), 91.1ms
# Speed: 1.2ms preprocess, 91.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# WARNING  no tracks found!
#
# 0: 320x640 (no detections),